# %%
import plotly.graph_objects as go
import numpy as np
import math

# f = open('/Users/cedricxing/Downloads/result/result_100.txt','r')
f = open('/Users/cedricxing/Documents/SEG/CPS_MPC/output/result/result_0.txt','r')
# f = open('/Users/cedricxing/Desktop/result.txt','r')
x = -30.0
y = 5.0
xArray = [[],[],[]]
yArray = [[],[],[]]
co = 0
angle = 0.0
v = 0
V = [[],[],[]]
T = [[],[],[]]
UpperBoundT = []
LowerBoundT = []
UpperBoundAngle = []
LowerBoundAngle = []
UpperBoundU1 = []
LowerBoundU1 = []
UpperBoundU2 = []
LowerBoundU2 = []
TALL = []
U1 = [[],[],[]]
U2 = [[],[],[]]
s = 0
Angle = [[],[],[]]
delta = 0.05
interval = 1
lines = f.readlines()
fuel = [[],[],[]]
Fuel = [[],[]]
sum_fuel = 0
for line in lines:
    if 'itera' in line or 'time' in line:
        continue
    solution = line.split("&")
    temp = solution[0].strip().split(",")
    print(temp)
    t = [0,0,0]
    u1 = 0
    u2 = 0
    if len(temp) == 3:
        t[int(temp[0])] = float(solution[1].strip())
        t[int(temp[1])] = float(solution[2].strip())
        u1 = float(solution[4].strip())
        u2 = float(solution[3].strip())
        i = 0
        if int(temp[0]) == 1:
            while i < t[1]:
                co = co + 1
                if co == interval:
                    xArray[1].append(x)
                    yArray[1].append(y)
                    V[1].append(v)
                    Angle[1].append(angle)
                    T[1].append(s)
                    UpperBoundT.append(8)
                    LowerBoundT.append(2)
                    UpperBoundAngle.append(3.14)
                    LowerBoundAngle.append(-1.5)
                    TALL.append(s)
                    U2[1].append(0)
                    U1[1].append(u1)
                    UpperBoundU1.append(0.3)
                    LowerBoundU1.append(-0.3)
                    UpperBoundU2.append(0.523)
                    LowerBoundU2.append(-0.523)
                    fuel[1].append(sum_fuel + abs(x-200) + abs(y-200))
                    Fuel[0].append(sum_fuel)
                    Fuel[1].append(sum_fuel+abs(x-200)+abs(y-200))
                    co = 0
                x = x + v * math.cos(angle) * delta
                y = y + v * math.sin(angle) * delta
                v = v + u1 * delta
                s = s + delta
                sum_fuel = sum_fuel + v * 0.5
                i = i + 1
            i = 0
            while i < t[2]:
                co = co + 1
                if co == interval:
                    xArray[2].append(x)
                    yArray[2].append(y)
                    V[2].append(v)
                    Angle[2].append(angle)
                    T[2].append(s)
                    UpperBoundT.append(8)
                    LowerBoundT.append(2)
                    UpperBoundAngle.append(3.14)
                    LowerBoundAngle.append(-1.5)
                    TALL.append(s)
                    U2[2].append(u2)
                    U1[2].append(0)
                    UpperBoundU1.append(0.3)
                    LowerBoundU1.append(-0.3)
                    UpperBoundU2.append(0.523)
                    LowerBoundU2.append(-0.523)
                    fuel[2].append(sum_fuel + abs(x-200)+abs(y-200))
                    Fuel[0].append(sum_fuel)
                    Fuel[1].append(sum_fuel+abs(x-200)+abs(y-200))
                    co = 0
                x = x + v * math.cos(angle) * delta
                y = y + v * math.sin(angle) * delta
                s = s + delta
                angle = angle + u2 * delta
                sum_fuel = sum_fuel + v * 0.5
                i = i + 1
        else :
            while i < t[2]:
                co = co + 1
                if co == interval:
                    xArray[2].append(x)
                    yArray[2].append(y)
                    V[2].append(v)
                    Angle[2].append(angle)
                    T[2].append(s)
                    UpperBoundT.append(8)
                    LowerBoundT.append(2)
                    UpperBoundAngle.append(3.14)
                    LowerBoundAngle.append(-1.5)
                    TALL.append(s)
                    U2[2].append(u2)
                    U1[2].append(0)
                    UpperBoundU1.append(0.3)
                    LowerBoundU1.append(-0.3)
                    UpperBoundU2.append(0.523)
                    LowerBoundU2.append(-0.523)
                    fuel[2].append(sum_fuel + abs(x-200)+abs(y-200))
                    Fuel[0].append(sum_fuel)
                    Fuel[1].append(sum_fuel+abs(x-200)+abs(y-200))
                    co = 0
                x = x + v * math.cos(angle) * delta
                y = y + v * math.sin(angle) * delta
                s = s + delta
                angle = angle + u2 * delta
                sum_fuel = sum_fuel + v * 0.5
                i = i + 1
            i = 0
            while i < t[1]:
                co = co + 1
                if co == interval:
                    xArray[1].append(x)
                    yArray[1].append(y)
                    V[1].append(v)
                    Angle[1].append(angle)
                    T[1].append(s)
                    UpperBoundT.append(8)
                    LowerBoundT.append(2)
                    UpperBoundAngle.append(3.14)
                    LowerBoundAngle.append(-1.5)
                    TALL.append(s)
                    U2[1].append(0)
                    U1[1].append(u1)
                    UpperBoundU1.append(0.3)
                    LowerBoundU1.append(-0.3)
                    UpperBoundU2.append(0.523)
                    LowerBoundU2.append(-0.523)
                    fuel[1].append(sum_fuel + abs(x-200)+abs(y-200))
                    Fuel[0].append(sum_fuel)
                    Fuel[1].append(sum_fuel+abs(x-200)+abs(y-200))
                    co = 0
                x = x + v * math.cos(angle) * delta
                y = y + v * math.sin(angle) * delta
                s = s + delta
                v = v + u1 * delta
                sum_fuel = sum_fuel + v * 0.5
                i = i + 1
    else:
        t[int(temp[0])] = float(solution[1].strip())
        u1 = float(solution[3].strip())
        u2 = float(solution[2].strip())
        print(t)
        print(u1)
        print(u2)
        i = 0
        while i < t[1]:
            co = co + 1
            if co == interval:
                xArray[1].append(x)
                yArray[1].append(y)
                V[1].append(v)
                Angle[1].append(angle)
                T[1].append(s)
                UpperBoundT.append(8)
                LowerBoundT.append(2)
                UpperBoundAngle.append(3.14)
                LowerBoundAngle.append(-1.5)
                TALL.append(s)
                U2[1].append(0)
                U1[1].append(u1)
                UpperBoundU1.append(0.3)
                LowerBoundU1.append(-0.3)
                UpperBoundU2.append(0.523)
                LowerBoundU2.append(-0.523)
                fuel[1].append(sum_fuel + abs(x-200)+abs(y-200))
                Fuel[0].append(sum_fuel)
                Fuel[1].append(sum_fuel+abs(x-200)+abs(y-200))
                co = 0
            x = x + v * math.cos(angle) * delta
            y = y + v * math.sin(angle) * delta
            v = v + u1 * delta
            s = s + delta
            sum_fuel = sum_fuel + v * 0.5
            i = i + 1
        i = 0
        while i < t[2]:
            co = co + 1
            if co == interval:
                xArray[2].append(x)
                yArray[2].append(y)
                V[2].append(v)
                Angle[2].append(angle)
                T[2].append(s)
                UpperBoundT.append(8)
                LowerBoundT.append(2)
                UpperBoundAngle.append(3.14)
                LowerBoundAngle.append(-1.5)
                TALL.append(s)
                U2[2].append(u2)
                U1[2].append(0)
                UpperBoundU1.append(0.3)
                LowerBoundU1.append(-0.3)
                UpperBoundU2.append(0.523)
                LowerBoundU2.append(-0.523)
                fuel[2].append(sum_fuel + abs(x-200)+abs(y-200))
                Fuel[0].append(sum_fuel)
                Fuel[1].append(sum_fuel+abs(x-200)+abs(y-200))
                co = 0
            x = x + v * math.cos(angle) * delta
            y = y + v * math.sin(angle) * delta
            s = s + delta
            angle = angle + u2 * delta
            sum_fuel = sum_fuel + v * 0.5
            i = i + 1
        # print('x:'+str(x))
        # print('y:'+str(y))
        # print('v:'+str(v))
        # print('angle:'+str(angle))

colors=['','#1f77b4', '#ff7f0e','#2ca02c']

layout1 = go.Layout(
#     width = 400,
#     height = 400,
    showlegend=False,
    xaxis=dict(
        #showline=True,
        showgrid=False,
        #showticklabels=False,
        #linewidth=2
        title = '',
        tickfont=dict(
            family='Arial',
            size=25,
        ),
    ),
    yaxis=dict(
        showgrid=False,
        #zeroline=False,
        #showline=True,
        #showticklabels=False,
        title='',
        tickfont=dict(
            family='Arial',
            size=25,
        ),
    )
)
layout2 = go.Layout(
#     width = 400,
#     height = 400,
    showlegend=False,
    xaxis=dict(
        #showline=True,
        showgrid=False,
        #showticklabels=False,
        #linewidth=2
        title = '',
        tickfont=dict(
            family='Arial',
            size=18,
        ),
    ),
    yaxis=dict(
        showgrid=False,
        #zeroline=False,
        #showline=True,
        #showticklabels=False,
        title='',
        tickfont=dict(
            family='Arial',
            size=18,
        ),
    )
)
layout3 = go.Layout(
#     width = 400,
#     height = 400,
    showlegend=False,
    xaxis=dict(
        #showline=True,
        showgrid=False,
        #showticklabels=False,
        #linewidth=2
        title = '',
        tickfont=dict(
            family='Arial',
            size=12,
        ),
    ),
    yaxis=dict(
        showgrid=False,
        #zeroline=False,
        #showline=True,
        #showticklabels=False,
        title='',
        tickfont=dict(
            family='Arial',
            size=18,
        ),
    )
)

layout4 = go.Layout(
#     width = 400,
#     height = 400,
    showlegend=False,
    xaxis=dict(
        #showline=True,
        showgrid=False,
        #showticklabels=False,
        #linewidth=2
        title = '',
        tickfont=dict(
            family='Arial',
#             size=18,
        ),
    ),
    yaxis=dict(
        showgrid=False,
        #zeroline=False,
        #showline=True,
        #showticklabels=False,
        title='',
        tickfont=dict(
            family='Arial',
#             size=30,
        ),
    )
)
layout5 = go.Layout(
#     width = 400,
#     height = 400,
    showlegend=False,
    xaxis=dict(
        showline=False,
        showgrid=False,
        #showticklabels=False,
        #linewidth=2
        title = '',
        tickfont=dict(
            family='Arial',
            size=18,
        ),
    ),
    yaxis=dict(
        showgrid=False,
        #zeroline=False,
        #showline=True,
        #showticklabels=False,
        title='',
        tickfont=dict(
            family='Arial',
            size=18,
        ),
    ),
    width=600,
    height=600
)

trace0 = go.Scatter(
        x=np.array(xArray),
        y=np.array(yArray),
        mode='markers',
        name='markers')
# trace1 = go.Scatter(
#         x=random_x,
#         y=random_y1,
#         mode='lines+markers',
#         name='markers')
# trace2 = go.Scatter(
#         x=random_x,
#         y=random_y2,
#         mode='lines',
#         name='markers')
fig = go.Figure()
fig.add_scatter(x=np.array(xArray[1]),y=np.array(yArray[1]),mode='markers',name='Forward Mode',line=dict(color=colors[1]))
fig.add_scatter(x=np.array(xArray[2]),y=np.array(yArray[2]),mode='markers',name='Turn Mode',line=dict(color=colors[2]))
# print(xArray[1]+xArray[2])
# print(yArray[1]+yArray[2])
fig1 = go.Figure(layout=layout1)
fig1.add_scatter(x=np.array(T[1]),y=np.array(V[1]),mode='markers',name='Forward Mode')
fig1.add_scatter(x=np.array(T[2]),y=np.array(V[2]),mode='markers',name='Turn Mode')
fig1.add_scatter(x=np.array(TALL),y=np.array(UpperBoundT),name='UpperBound',line = dict(
        color = ('red'),
        width = 1,
        dash = 'dash'))
fig1.add_scatter(x=np.array(TALL),y=np.array(LowerBoundT),name='LowerBound',line = dict(
        color = ('magenta'),
        width = 1,
        dash = 'dash'))

fig2 = go.Figure(layout=layout2)
fig2.add_scatter(x=np.array(T[1]),y=np.array(Angle[1]),mode='markers',name='Forward Mode')
fig2.add_scatter(x=np.array(T[2]),y=np.array(Angle[2]),mode='markers',name='Turn Mode')
print(Angle[1]+Angle[2])
fig2.add_scatter(x=np.array(TALL),y=np.array(UpperBoundAngle),name='UpperBound',line = dict(
        color = ('red'),
        width = 1,
        dash = 'dash'))
fig2.add_scatter(x=np.array(TALL),y=np.array(LowerBoundAngle),name='LowerBound',line = dict(
        color = ('magenta'),
        width = 1,
        dash = 'dash'))

fig3 = go.Figure(layout=layout3)
# fig3 = go.Figure()
fig3.add_scatter(x=np.array(T[1]),y=np.array(U1[1]),mode='markers',name='Forward Mode',line=dict(color=colors[1]))
fig3.add_scatter(x=np.array(T[2]),y=np.array(U1[2]),mode='markers',name='Turn Mode',line=dict(color=colors[2]))
# fig3.add_scatter(x=np.array(TALL),y=np.array(UpperBoundU1),name='UpperBound',line = dict(
#         color = ('indianred'),
#         width = 1,
#         dash = 'dash'))
# fig3.add_scatter(x=np.array(TALL),y=np.array(LowerBoundU1),name='LowerBound',line = dict(
#         color = ('indianred'),
#         width = 1,
#         dash = 'dash'))

fig4 = go.Figure(layout=layout4)
fig4.add_scatter(x=np.array(T[1]),y=np.array(U2[1]),mode='markers',name='Forward Mode',line=dict(color=colors[1]))
fig4.add_scatter(x=np.array(T[2]),y=np.array(U2[2]),mode='markers',name='Turn Mode',line=dict(color=colors[2]))
# fig4.add_scatter(x=np.array(TALL),y=np.array(UpperBoundU2),name='UpperBound',line = dict(
#         color = ('indianred'),
#         width = 1,
#         dash = 'dash'))
# fig4.add_scatter(x=np.array(TALL),y=np.array(LowerBoundU2),name='LowerBound',line = dict(
#         color = ('indianred'),
#         width = 1,
#         dash = 'dash'))

# fig5 = go.Figure(layout=layout5)

# fig5.add_scatter(x=np.array(T[1]),y=np.array(fuel[1]),mode='markers',name='')
# fig5.add_scatter(x=np.array(T[2]),y=np.array(fuel[2]),mode='markers',name='')
# fig5.add_scatter(x=np.array([T[2][len(T[2])-1],T[2][len(T[2])-1]]),y=np.array([fuel[2][len(fuel[2])-1],0]),mode='lines',line = dict(
#         color = ('brown'),
#         width = 1,
#         dash = 'dash'))
# fig5.add_scatter(x=np.array([T[2][len(T[2])-1],0]),y=np.array([fuel[2][len(fuel[2])-1],fuel[2][len(fuel[2])-1]]),mode='lines',line = dict(
#         color = ('brown'),
#         width = 1,
#         dash = 'dash'))

obstacles_color = 'indianred'
layout = {
    'showlegend':True,
    'xaxis': {
        'range': [-31, 10],
        'title':'',
        'showgrid':False,
        'tickfont':{
            'family':'Arial',
            'size':12,
        },
        #'zeroline': False,
    },
    'yaxis': {
        'range': [-31, 10],
        'title':'',
        'showgrid':False,
        'tickfont':{
            'family':'Arial',
            'size':12,
        },
    },
    'width': 600,
    'height': 600,
    'shapes': [
        {
            'type': 'circle',
            'xref': 'x',
            'yref': 'y',
            'x0': -30.5,
            'y0': 5.5,
            'x1': -29.5,
            'y1': 4.5,
            'line': {
                'color': 'green',
            },
            'fillcolor':'green'
        },
        {
            'type': 'circle',
            'xref': 'x',
            'yref': 'y',
            'x0': 0.5,
            'y0': -8.5,
            'x1': 1.5,
            'y1': -7.5,
            'line': {
                'color': 'green',
            },
            'fillcolor':'green'
        },
        {
            'type': 'rect',
            'x0': -40,
            'y0': -2,
            'x1': -7,
            'y1': -40,
            'line': {
                'color': obstacles_color,
            },
        },
        {
            'type': 'rect',
            'x0': -40,
            'y0': 9,
            'x1': -5,
            'y1': 30,
            'line': {
                'color': obstacles_color,
            },
        },
        {
            'type': 'rect',
            'x0': 9,
            'y0': -40,
            'x1': 20,
            'y1': -2,
            'line': {
                'color': obstacles_color,
            },
        },
        {
            'type': 'rect',
            'x0': 9,
            'y0': 9,
            'x1': 20,
            'y1': 20,
            'line': {
                'color': obstacles_color,
            },
        },
    ]
}
layout1 = {}
fig.layout = layout
fig.update_layout(legend_orientation="h")
fig.update_layout(xaxis=dict(tickfont=dict(
            family='Arial',
            size=25,
        )),yaxis=dict(tickfont=dict(
            family='Arial',
            size=25,)))
#fig1.layout = layout1
#data=[trace0,trace1,trace2]
fig.show()
fig1.show()
fig2.show()
fig3.update_layout(yaxis=go.layout.YAxis(range=[-0.35,0.35]))
fig3.update_layout(showlegend=False)
fig3.update_layout(xaxis=dict(tickfont=dict(
            family='Arial',
            size=30,
        )),yaxis=dict(tickfont=dict(
            family='Arial',
            size=30,)))
fig3.show()

fig4.update_layout(yaxis=go.layout.YAxis(range=[-2,2]))
fig4.update_layout(xaxis=dict(tickfont=dict(
            family='Arial',
            size=30,
        )),yaxis=dict(tickfont=dict(
            family='Arial',
            size=30,)))
# fig4.update_layout(title='Average High and Low Temperatures in New York',
#                    xaxis_title='t',
#                    yaxis_title='u1')
fig4.show()

# fig5.show()
fig.write_image('/Users/cedricxing/Desktop/v_trace.pdf')
# fig3.write_image('/Users/cedricxing/Desktop/v_u1.pdf')
# fig4.write_image('/Users/cedricxing/Desktop/v_u2.pdf')
# Out:
# ['1', '']
# [0, 200.0, 0]
# 0.4999999999999848
# 0.713163358198182
# ['2', '1', '']
# ...
